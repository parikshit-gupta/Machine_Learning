# %% [markdown]
# # pandas
# ML Developer Stack(2)

# %%
import pandas as pd
import numpy as np
read_obj=pd.read_csv("terrorismData.csv")
#all data of the given csv file is loaded into the reader object
print(type(read_obj))
read_obj
read_obj1=read_obj#just a reference to the original reader obj
read_obj2=read_obj.copy()#creates an exact replica of the original dataset

#by default the top row of the csv file is takes a s the header of the pandas obj
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
class integer:
    def __init__(self, n:int):
        self.x=n       
    pass
a=integer(1)
print(a.x)
b=a
a.x=2
print(b.x)
print(a.x)
# Out:
# 1
# 2
# 2

# %%
#returns a panadas data frame with the first 5 columns by default
read_obj1.head()
read_obj1.head(3)
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
#
#             City   Latitude   Longitude                   AttackType  Killed  \
# 0  Santo Domingo  18.456792  -69.951164                Assassination     1.0
# 1    Mexico city  19.371887  -99.086624  Hostage Taking (Kidnapping)     0.0
# 2        Unknown  15.478598  120.599741                Assassination     1.0
#
#    Wounded                   Target Summary  \
# 0      0.0             Julio Guzman     NaN
# 1      0.0  Nadine Chaval, daughter     NaN
# 2      0.0                 Employee     NaN
#
#                                 Group                  Target_type Weapon_type
# 0                              MANO-D  Private Citizens & Property     Unknown
# ...

# %%
read_obj1.columns=['Year1', 'Month1', 'Day1', 'Country1', 'State1', 'Region1', 'City1',
       'Latitude1', 'Longitude1', 'AttackType1', 'Killed1', 'Wounded1', 'Target1',
       'Summary1', 'Group1', 'Target_type1', 'Weapon_type1']
read_obj1
#read_obj1.columns=['year1'] gives an error, provide names for all columns of the datatable
# Out:
#         Year1  Month1  Day1            Country1           State1  \
# 0        1970       7     2  Dominican Republic              NaN
# 1        1970       0     0              Mexico          Federal
# 2        1970       1     0         Philippines           Tarlac
# 3        1970       1     0              Greece           Attica
# 4        1970       1     0               Japan          Fukouka
# ...       ...     ...   ...                 ...              ...
# 181686   2017      12    31             Somalia  Middle Shebelle
# 181687   2017      12    31               Syria         Lattakia
# 181688   2017      12    31         Philippines      Maguindanao
# 181689   2017      12    31               India          Manipur
# 181690   2017      12    31         Philippines      Maguindanao
#
#                             Region1          City1  Latitude1  Longitude1  \
# 0       Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# ...

# %%
#these functions/ attributes help in getting an overview of the data we are dealing with
print(read_obj1.shape)
print(read_obj1.dtypes)
read_obj1.describe()
#count row returned by the describe funciton counts the non NULL values in that pirticular column only
#thus the value of count for diff columns will be different
# Out:
# (181691, 17)
# Year1             int64
# Month1            int64
# Day1              int64
# Country1         object
# State1           object
# Region1          object
# City1            object
# Latitude1       float64
# Longitude1      float64
# AttackType1      object
# Killed1         float64
# Wounded1        float64
# Target1          object
# Summary1         object
# Group1           object
# Target_type1     object
# Weapon_type1     object
# dtype: object
#                Year1         Month1           Day1      Latitude1  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# ...

# %%
read_obj.Year1
read_obj['Country1']
# Out:
# 0         Dominican Republic
# 1                     Mexico
# 2                Philippines
# 3                     Greece
# 4                      Japan
#                  ...
# 181686               Somalia
# 181687                 Syria
# 181688           Philippines
# 181689                 India
# 181690           Philippines
# Name: Country1, Length: 181691, dtype: object

# %%
#returns the original table as a boolean table with false at all tose places with value not NULL
read_obj.isnull()
read_obj1.isnull().sum()#returns the total number of values in each columns which are null
# Out:
# Year1               0
# Month1              0
# Day1                0
# Country1            0
# State1            421
# Region1             0
# City1             435
# Latitude1        4556
# Longitude1       4557
# AttackType1         0
# Killed1         10313
# Wounded1        16311
# Target1           638
# Summary1        66129
# Group1              0
# Target_type1        0
# Weapon_type1        0
# dtype: int64

# %%
#this funcuton is used to acces certain blocks of data fron the given file
read_obj1.iloc[1:10,0:5]
# Out:
#    Year1  Month1  Day1       Country1      State1
# 1   1970       0     0         Mexico     Federal
# 2   1970       1     0    Philippines      Tarlac
# 3   1970       1     0         Greece      Attica
# 4   1970       1     0          Japan     Fukouka
# 5   1970       1     1  United States    Illinois
# 6   1970       1     2        Uruguay  Montevideo
# 7   1970       1     2  United States  California
# 8   1970       1     2  United States   Wisconsin
# 9   1970       1     3  United States   Wisconsin

# %%
a=read_obj1.drop(0, inpalce=False)
a.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 a=read_obj1.drop(0, inpalce=False)
#       2 a.head()
#
# TypeError: drop() got an unexpected keyword argument 'inpalce'

# %%
a=read_obj1.drop(2, inplace=False)
a.head()
#gives an error because the row with label 0 has aldready been deleted
# Out:
#    Year1  Month1  Day1       Country1      State1         Region1       City1  \
# 3   1970       1     0         Greece      Attica  Western Europe      Athens
# 4   1970       1     0          Japan     Fukouka       East Asia     Fukouka
# 5   1970       1     1  United States    Illinois   North America       Cairo
# 6   1970       1     2        Uruguay  Montevideo   South America  Montevideo
# 7   1970       1     2  United States  California   North America     Oakland
#
#    Latitude1  Longitude1                     AttackType1  Killed1  Wounded1  \
# 3  37.997490   23.762728               Bombing/Explosion      NaN       NaN
# 4  33.580412  130.396361  Facility/Infrastructure Attack      NaN       NaN
# 5  37.005105  -89.176269                   Armed Assault      0.0       0.0
# 6 -34.891151  -56.187214                   Assassination      0.0       0.0
# 7  37.791927 -122.225906               Bombing/Explosion      0.0       0.0
#
# ...

# %%
read_obj1.drop(2, inplace=False)
read_obj1.head()
# Out:
#    Year1  Month1  Day1       Country1      State1         Region1       City1  \
# 2   1970       1     0    Philippines      Tarlac  Southeast Asia     Unknown
# 3   1970       1     0         Greece      Attica  Western Europe      Athens
# 4   1970       1     0          Japan     Fukouka       East Asia     Fukouka
# 5   1970       1     1  United States    Illinois   North America       Cairo
# 6   1970       1     2        Uruguay  Montevideo   South America  Montevideo
#
#    Latitude1  Longitude1                     AttackType1  Killed1  Wounded1  \
# 2  15.478598  120.599741                   Assassination      1.0       0.0
# 3  37.997490   23.762728               Bombing/Explosion      NaN       NaN
# 4  33.580412  130.396361  Facility/Infrastructure Attack      NaN       NaN
# 5  37.005105  -89.176269                   Armed Assault      0.0       0.0
# 6 -34.891151  -56.187214                   Assassination      0.0       0.0
#
# ...

# %%
read_obj1.index#returns a list of the row indices
read_obj1.drop(read_obj1.index[1], inplace =True)
read_obj1.index
# Out:
# Index([     2,      5,      6,      7,      8,      9,     10,     11,     12,
#            13,
#        ...
#        181681, 181682, 181683, 181684, 181685, 181686, 181687, 181688, 181689,
#        181690],
#       dtype='int64', length=181687)

# %%
c1=read_obj1[read_obj1.Country1=='India']
c1.shape
# Out:
# (11960, 17)

# %%
print(read_obj1.iloc[0])
print(read_obj1.iloc[0:5])
# Out:
# Year1                          1970
# Month1                            1
# Day1                              0
# Country1                Philippines
# State1                       Tarlac
# Region1              Southeast Asia
# City1                       Unknown
# Latitude1                 15.478598
# Longitude1               120.599741
# AttackType1           Assassination
# Killed1                         1.0
# Wounded1                        0.0
# Target1                    Employee
# Summary1                        NaN
# Group1                      Unknown
# Target_type1    Journalists & Media
# Weapon_type1                Unknown
# Name: 2, dtype: object
#    Year1  Month1  Day1       Country1      State1         Region1       City1  \
# 2   1970       1     0    Philippines      Tarlac  Southeast Asia     Unknown
# 5   1970       1     1  United States    Illinois   North America       Cairo
# 6   1970       1     2        Uruguay  Montevideo   South America  Montevideo
# ...

# %%
read_obj1.loc[8]
#returns the rows according to their labels
#adds that row to the end of the tbale if the label is not aldready present in the table
#read_obj.loc[1]=[list of correspoding items]
# Out:
# Year1                                                        1970
# Month1                                                          1
# Day1                                                            2
# Country1                                            United States
# State1                                                  Wisconsin
# Region1                                             North America
# City1                                                     Madison
# Latitude1                                               43.076592
# Longitude1                                             -89.412488
# AttackType1                        Facility/Infrastructure Attack
# Killed1                                                       0.0
# Wounded1                                                      0.0
# Target1         R.O.T.C. offices at University of Wisconsin, M...
# Summary1        1/2/1970: Karl Armstrong, a member of the New ...
# ...

# %%
read_obj1.tail()
# Out:
#         Year1  Month1  Day1     Country1           State1  \
# 181686   2017      12    31      Somalia  Middle Shebelle
# 181687   2017      12    31        Syria         Lattakia
# 181688   2017      12    31  Philippines      Maguindanao
# 181689   2017      12    31        India          Manipur
# 181690   2017      12    31  Philippines      Maguindanao
#
#                            Region1          City1  Latitude1  Longitude1  \
# 181686          Sub-Saharan Africa  Ceelka Geelow   2.359673   45.385034
# 181687  Middle East & North Africa         Jableh  35.407278   35.942679
# 181688              Southeast Asia       Kubentog   6.900742  124.437908
# 181689                  South Asia         Imphal  24.798346   93.940430
# 181690              Southeast Asia  Cotabato City   7.209594  124.241966
#
#                            AttackType1  Killed1  Wounded1           Target1  \
# 181686                   Armed Assault      1.0       2.0        Checkpoint
# ...

# %%
read_obj1['month_day']=read_obj1['Month1']+read_obj1['Day1']
read_obj1.head()
# Out:
#    Year1  Month1  Day1       Country1      State1         Region1       City1  \
# 2   1970       1     0    Philippines      Tarlac  Southeast Asia     Unknown
# 5   1970       1     1  United States    Illinois   North America       Cairo
# 6   1970       1     2        Uruguay  Montevideo   South America  Montevideo
# 7   1970       1     2  United States  California   North America     Oakland
# 8   1970       1     2  United States   Wisconsin   North America     Madison
#
#    Latitude1  Longitude1                     AttackType1  Killed1  Wounded1  \
# 2  15.478598  120.599741                   Assassination      1.0       0.0
# 5  37.005105  -89.176269                   Armed Assault      0.0       0.0
# 6 -34.891151  -56.187214                   Assassination      0.0       0.0
# 7  37.791927 -122.225906               Bombing/Explosion      0.0       0.0
# 8  43.076592  -89.412488  Facility/Infrastructure Attack      0.0       0.0
#
# ...

# %%
read_obj1.iloc[0:5,10]=np.nan
read_obj1.head()
# Out:
#    Year1  Month1  Day1            Country1   State1  \
# 0   1970       7     2  Dominican Republic      NaN
# 1   1970       0     0              Mexico  Federal
# 2   1970       1     0         Philippines   Tarlac
# 3   1970       1     0              Greece   Attica
# 4   1970       1     0               Japan  Fukouka
#
#                        Region1          City1  Latitude1  Longitude1  \
# 0  Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# 1                North America    Mexico city  19.371887  -99.086624
# 2               Southeast Asia        Unknown  15.478598  120.599741
# 3               Western Europe         Athens  37.997490   23.762728
# 4                    East Asia        Fukouka  33.580412  130.396361
#
#                       AttackType1  Killed1  Wounded1                  Target1  \
# 0                   Assassination      NaN       0.0             Julio Guzman
# ...

# %%
read_obj1.Killed1.fillna(read_obj1.Killed1.mean(), inplace=True)
read_obj1.head()
# Out:
#    Year1  Month1  Day1            Country1   State1  \
# 0   1970       7     2  Dominican Republic      NaN
# 1   1970       0     0              Mexico  Federal
# 2   1970       1     0         Philippines   Tarlac
# 3   1970       1     0              Greece   Attica
# 4   1970       1     0               Japan  Fukouka
#
#                        Region1          City1  Latitude1  Longitude1  \
# 0  Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# 1                North America    Mexico city  19.371887  -99.086624
# 2               Southeast Asia        Unknown  15.478598  120.599741
# 3               Western Europe         Athens  37.997490   23.762728
# 4                    East Asia        Fukouka  33.580412  130.396361
#
#                       AttackType1   Killed1  Wounded1  \
# 0                   Assassination  2.403303       0.0
# 1     Hostage Taking (Kidnapping)  2.403303       0.0
# 2                   Assassination  2.403303       0.0
# ...

# %%
read_obj1.fillna(read_obj1.Killed1.mean())
# Out:
#         Year1  Month1  Day1            Country1           State1  \
# 0        1970       7     2  Dominican Republic         2.403303
# 1        1970       0     0              Mexico          Federal
# 2        1970       1     0         Philippines           Tarlac
# 3        1970       1     0              Greece           Attica
# 4        1970       1     0               Japan          Fukouka
# ...       ...     ...   ...                 ...              ...
# 181686   2017      12    31             Somalia  Middle Shebelle
# 181687   2017      12    31               Syria         Lattakia
# 181688   2017      12    31         Philippines      Maguindanao
# 181689   2017      12    31               India          Manipur
# 181690   2017      12    31         Philippines      Maguindanao
#
#                             Region1          City1  Latitude1  Longitude1  \
# 0       Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# ...

# %%
read_obj2=read_obj.copy()

# %%
read_obj2['gender']='male'
read_obj2.iloc[0:10:2,17]='female'
read_obj2.head(10)
# Out:
#    Year1  Month1  Day1            Country1      State1  \
# 0   1970       7     2  Dominican Republic         NaN
# 1   1970       0     0              Mexico     Federal
# 2   1970       1     0         Philippines      Tarlac
# 3   1970       1     0              Greece      Attica
# 4   1970       1     0               Japan     Fukouka
# 5   1970       1     1       United States    Illinois
# 6   1970       1     2             Uruguay  Montevideo
# 7   1970       1     2       United States  California
# 8   1970       1     2       United States   Wisconsin
# 9   1970       1     3       United States   Wisconsin
#
#                        Region1          City1  Latitude1  Longitude1  \
# 0  Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# 1                North America    Mexico city  19.371887  -99.086624
# 2               Southeast Asia        Unknown  15.478598  120.599741
# 3               Western Europe         Athens  37.997490   23.762728
# ...

# %%
def f(s):
    if s=='male':
        return 1
    else:
        return 0

read_obj2['gender']=read_obj2.gender.apply(f)
(read_obj2.head(10))
# Out:
#    Year1  Month1  Day1            Country1      State1  \
# 0   1970       7     2  Dominican Republic         NaN
# 1   1970       0     0              Mexico     Federal
# 2   1970       1     0         Philippines      Tarlac
# 3   1970       1     0              Greece      Attica
# 4   1970       1     0               Japan     Fukouka
# 5   1970       1     1       United States    Illinois
# 6   1970       1     2             Uruguay  Montevideo
# 7   1970       1     2       United States  California
# 8   1970       1     2       United States   Wisconsin
# 9   1970       1     3       United States   Wisconsin
#
#                        Region1          City1  Latitude1  Longitude1  \
# 0  Central America & Caribbean  Santo Domingo  18.456792  -69.951164
# 1                North America    Mexico city  19.371887  -99.086624
# 2               Southeast Asia        Unknown  15.478598  120.599741
# 3               Western Europe         Athens  37.997490   23.762728
# ...

# %%
print((read_obj2.gender[111]))
print((read_obj2.gender.index[111]))
# Out:
# 1
# 111
