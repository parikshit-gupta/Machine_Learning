# %% [markdown]
# ### Bias and variance
# - Here we just demonstrate the difference between bias and variance.
# - Any ML problem has a true underlying function(f(x)) from which the training data is sampled, this f(x) will never be known to us. We try to model f(x) using our knowledge of the system to come up with a hypothesis function F(x).
# - We fit this F(x) to the training data to minimise a loss function.
# - In this notebook we take f(x) = sin(x), sample some 100 points from it, use these points to fit 2 possible F(x) and observe.

# %%
import numpy as np
import keras
